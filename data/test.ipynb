# %%
import pandas as pd

# %%
df = pd.read_csv('raw/top_10000_1960-now.csv')

# %%
df.head()
# Out:
#                               Track URI  \
# 0  spotify:track:1XAZlnVtthcDZt2NI1Dtxo
# 1  spotify:track:6a8GbQIlV8HBUW3c6Uk9PH
# 2  spotify:track:70XtWbcVZcpaOddJftMcVi
# 3  spotify:track:1NXUWyPJk5kO6DQJ5t7bDu
# 4  spotify:track:72WZtWs6V7uu3aMgMmEkYe
#
#                                 Track Name  \
# 0  Justified & Ancient - Stand by the Jams
# 1          I Know You Want Me (Calle Ocho)
# 2       From the Bottom of My Broken Heart
# 3         Apeman - 2014 Remastered Version
# 4       You Can't Always Get What You Want
#
#                            Artist URI(s)      Artist Name(s)  \
# 0  spotify:artist:6dYrdRlNZSKaVxYg5IrvCH             The KLF
# 1  spotify:artist:0TnOYISbd1XYRBk9myaseg             Pitbull
# 2  spotify:artist:26dSoYclwsYLMAKD3tpOr4      Britney Spears
# 3  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E           The Kinks
# 4  spotify:artist:22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
#
#                               Album URI  \
# 0  spotify:album:4MC0ZjNtVP1nDD5lsLxFjc
# 1  spotify:album:5xLAcbvbSAlRtPXnKkggXA
# 2  spotify:album:3WNxdumkSMGMJRhEgK80qx
# 3  spotify:album:6lL6HugNEN4Vlc8sj0Zcse
# 4  spotify:album:0c78nsgqX6VfniSNWIxwoD
#
#                                           Album Name  \
# 0                                   Songs Collection
# 1                     Pitbull Starring In Rebelution
# 2     ...Baby One More Time (Digital Deluxe Version)
# 3  Lola vs. Powerman and the Moneygoround, Pt. On...
# 4                                       Let It Bleed
#
#                      Album Artist URI(s) Album Artist Name(s)  \
# 0  spotify:artist:6dYrdRlNZSKaVxYg5IrvCH              The KLF
# 1  spotify:artist:0TnOYISbd1XYRBk9myaseg              Pitbull
# 2  spotify:artist:26dSoYclwsYLMAKD3tpOr4       Britney Spears
# 3  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E            The Kinks
# 4  spotify:artist:22bE4uQ6baNwSHPVcDxLCe   The Rolling Stones
#
#   Album Release Date                                    Album Image URL  ...  \
# 0         1992-08-03  https://i.scdn.co/image/ab67616d0000b27355346b...  ...
# 1         2009-10-23  https://i.scdn.co/image/ab67616d0000b27326d73a...  ...
# 2         1999-01-12  https://i.scdn.co/image/ab67616d0000b2738e4986...  ...
# 3         2014-10-20  https://i.scdn.co/image/ab67616d0000b2731e7c53...  ...
# 4         1969-12-05  https://i.scdn.co/image/ab67616d0000b27373d927...  ...
#
#    Speechiness  Acousticness  Instrumentalness Liveness  Valence    Tempo  \
# 0       0.0480        0.0158          0.112000   0.4080    0.504  111.458
# 1       0.1490        0.0142          0.000021   0.2370    0.800  127.045
# 2       0.0305        0.5600          0.000001   0.3380    0.706   74.981
# 3       0.2590        0.5680          0.000051   0.0384    0.833   75.311
# 4       0.0687        0.6750          0.000073   0.2890    0.497   85.818
#
#   Time Signature Album Genres                                Label  \
# 0            4.0          NaN                  Jams Communications
# 1            4.0          NaN  Mr.305/Polo Grounds Music/J Records
# 2            4.0          NaN                                 Jive
# 3            4.0          NaN                    Sanctuary Records
# 4            4.0          NaN                Universal Music Group
#
#                                           Copyrights
# 0  C 1992 Copyright Control, P 1992 Jams Communic...
# 1  P (P) 2009 RCA/JIVE Label Group, a unit of Son...
# 2                     P (P) 1999 Zomba Recording LLC
# 3  C © 2014 Sanctuary Records Group Ltd., a BMG C...
# 4  C © 2002 ABKCO Music & Records Inc., P ℗ 2002 ...
#
# [5 rows x 35 columns]

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns = df.columns.str.replace('(', '').str.replace(')', '')
df = df.drop(columns=['added_at', 'added_by'])
df.head()
# Out:
#                               track_uri  \
# 0  spotify:track:1XAZlnVtthcDZt2NI1Dtxo
# 1  spotify:track:6a8GbQIlV8HBUW3c6Uk9PH
# 2  spotify:track:70XtWbcVZcpaOddJftMcVi
# 3  spotify:track:1NXUWyPJk5kO6DQJ5t7bDu
# 4  spotify:track:72WZtWs6V7uu3aMgMmEkYe
#
#                                 track_name  \
# 0  Justified & Ancient - Stand by the Jams
# 1          I Know You Want Me (Calle Ocho)
# 2       From the Bottom of My Broken Heart
# 3         Apeman - 2014 Remastered Version
# 4       You Can't Always Get What You Want
#
#                              artist_uris        artist_names  \
# 0  spotify:artist:6dYrdRlNZSKaVxYg5IrvCH             The KLF
# 1  spotify:artist:0TnOYISbd1XYRBk9myaseg             Pitbull
# 2  spotify:artist:26dSoYclwsYLMAKD3tpOr4      Britney Spears
# 3  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E           The Kinks
# 4  spotify:artist:22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
#
#                               album_uri  \
# 0  spotify:album:4MC0ZjNtVP1nDD5lsLxFjc
# 1  spotify:album:5xLAcbvbSAlRtPXnKkggXA
# 2  spotify:album:3WNxdumkSMGMJRhEgK80qx
# 3  spotify:album:6lL6HugNEN4Vlc8sj0Zcse
# 4  spotify:album:0c78nsgqX6VfniSNWIxwoD
#
#                                           album_name  \
# 0                                   Songs Collection
# 1                     Pitbull Starring In Rebelution
# 2     ...Baby One More Time (Digital Deluxe Version)
# 3  Lola vs. Powerman and the Moneygoround, Pt. On...
# 4                                       Let It Bleed
#
#                        album_artist_uris  album_artist_names  \
# 0  spotify:artist:6dYrdRlNZSKaVxYg5IrvCH             The KLF
# 1  spotify:artist:0TnOYISbd1XYRBk9myaseg             Pitbull
# 2  spotify:artist:26dSoYclwsYLMAKD3tpOr4      Britney Spears
# 3  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E           The Kinks
# 4  spotify:artist:22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
#
#   album_release_date                                    album_image_url  ...  \
# 0         1992-08-03  https://i.scdn.co/image/ab67616d0000b27355346b...  ...
# 1         2009-10-23  https://i.scdn.co/image/ab67616d0000b27326d73a...  ...
# 2         1999-01-12  https://i.scdn.co/image/ab67616d0000b2738e4986...  ...
# 3         2014-10-20  https://i.scdn.co/image/ab67616d0000b2731e7c53...  ...
# 4         1969-12-05  https://i.scdn.co/image/ab67616d0000b27373d927...  ...
#
#    speechiness  acousticness  instrumentalness liveness  valence    tempo  \
# 0       0.0480        0.0158          0.112000   0.4080    0.504  111.458
# 1       0.1490        0.0142          0.000021   0.2370    0.800  127.045
# 2       0.0305        0.5600          0.000001   0.3380    0.706   74.981
# 3       0.2590        0.5680          0.000051   0.0384    0.833   75.311
# 4       0.0687        0.6750          0.000073   0.2890    0.497   85.818
#
#   time_signature album_genres                                label  \
# 0            4.0          NaN                  Jams Communications
# 1            4.0          NaN  Mr.305/Polo Grounds Music/J Records
# 2            4.0          NaN                                 Jive
# 3            4.0          NaN                    Sanctuary Records
# 4            4.0          NaN                Universal Music Group
#
#                                           copyrights
# 0  C 1992 Copyright Control, P 1992 Jams Communic...
# 1  P (P) 2009 RCA/JIVE Label Group, a unit of Son...
# 2                     P (P) 1999 Zomba Recording LLC
# 3  C © 2014 Sanctuary Records Group Ltd., a BMG C...
# 4  C © 2002 ABKCO Music & Records Inc., P ℗ 2002 ...
#
# [5 rows x 33 columns]

# %%
df = df.rename(columns={'track_uri': 'track_id','artist_uris': 'artist_id','album_uri':'album_id', 'album_artist_uris':'album_artist_id'})

df['album_id'] = df['album_id'].str.replace('spotify:album:', '', regex=False)
df['album_artist_id'] = df['album_artist_id'].str.replace('spotify:artist:', '', regex=False)
df['track_id'] = df['track_id'].str.replace('spotify:track:', '', regex=False)
df.head()
# Out:
#                  track_id                               track_name  \
# 0  1XAZlnVtthcDZt2NI1Dtxo  Justified & Ancient - Stand by the Jams
# 1  6a8GbQIlV8HBUW3c6Uk9PH          I Know You Want Me (Calle Ocho)
# 2  70XtWbcVZcpaOddJftMcVi       From the Bottom of My Broken Heart
# 3  1NXUWyPJk5kO6DQJ5t7bDu         Apeman - 2014 Remastered Version
# 4  72WZtWs6V7uu3aMgMmEkYe       You Can't Always Get What You Want
#
#                                artist_id        artist_names  \
# 0  spotify:artist:6dYrdRlNZSKaVxYg5IrvCH             The KLF
# 1  spotify:artist:0TnOYISbd1XYRBk9myaseg             Pitbull
# 2  spotify:artist:26dSoYclwsYLMAKD3tpOr4      Britney Spears
# 3  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E           The Kinks
# 4  spotify:artist:22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
#
#                  album_id                                         album_name  \
# 0  4MC0ZjNtVP1nDD5lsLxFjc                                   Songs Collection
# 1  5xLAcbvbSAlRtPXnKkggXA                     Pitbull Starring In Rebelution
# 2  3WNxdumkSMGMJRhEgK80qx     ...Baby One More Time (Digital Deluxe Version)
# 3  6lL6HugNEN4Vlc8sj0Zcse  Lola vs. Powerman and the Moneygoround, Pt. On...
# 4  0c78nsgqX6VfniSNWIxwoD                                       Let It Bleed
#
#           album_artist_id  album_artist_names album_release_date  \
# 0  6dYrdRlNZSKaVxYg5IrvCH             The KLF         1992-08-03
# 1  0TnOYISbd1XYRBk9myaseg             Pitbull         2009-10-23
# 2  26dSoYclwsYLMAKD3tpOr4      Britney Spears         1999-01-12
# 3  1SQRv42e4PjEYfPhS0Tk9E           The Kinks         2014-10-20
# 4  22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones         1969-12-05
#
#                                      album_image_url  ...  speechiness  \
# 0  https://i.scdn.co/image/ab67616d0000b27355346b...  ...       0.0480
# 1  https://i.scdn.co/image/ab67616d0000b27326d73a...  ...       0.1490
# 2  https://i.scdn.co/image/ab67616d0000b2738e4986...  ...       0.0305
# 3  https://i.scdn.co/image/ab67616d0000b2731e7c53...  ...       0.2590
# 4  https://i.scdn.co/image/ab67616d0000b27373d927...  ...       0.0687
#
#    acousticness  instrumentalness liveness  valence    tempo time_signature  \
# 0        0.0158          0.112000   0.4080    0.504  111.458            4.0
# 1        0.0142          0.000021   0.2370    0.800  127.045            4.0
# 2        0.5600          0.000001   0.3380    0.706   74.981            4.0
# 3        0.5680          0.000051   0.0384    0.833   75.311            4.0
# 4        0.6750          0.000073   0.2890    0.497   85.818            4.0
#
#   album_genres                                label  \
# 0          NaN                  Jams Communications
# 1          NaN  Mr.305/Polo Grounds Music/J Records
# 2          NaN                                 Jive
# 3          NaN                    Sanctuary Records
# 4          NaN                Universal Music Group
#
#                                           copyrights
# 0  C 1992 Copyright Control, P 1992 Jams Communic...
# 1  P (P) 2009 RCA/JIVE Label Group, a unit of Son...
# 2                     P (P) 1999 Zomba Recording LLC
# 3  C © 2014 Sanctuary Records Group Ltd., a BMG C...
# 4  C © 2002 ABKCO Music & Records Inc., P ℗ 2002 ...
#
# [5 rows x 33 columns]

# %%
#df = df.set_index('track_id')
df = df.drop(columns=['track_preview_url', 'album_genres', 'copyrights', 'label'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 #df = df.set_index('track_id')
# ----> 2 df = df.drop(columns=['track_preview_url', 'album_genres', 'copyrights', 'label'])
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['track_preview_url', 'album_genres', 'copyrights'] not found in axis"

# %%
df.head()
# Out:
#                  track_id                               track_name  \
# 0  1XAZlnVtthcDZt2NI1Dtxo  Justified & Ancient - Stand by the Jams
# 1  6a8GbQIlV8HBUW3c6Uk9PH          I Know You Want Me (Calle Ocho)
# 2  70XtWbcVZcpaOddJftMcVi       From the Bottom of My Broken Heart
# 3  1NXUWyPJk5kO6DQJ5t7bDu         Apeman - 2014 Remastered Version
# 4  72WZtWs6V7uu3aMgMmEkYe       You Can't Always Get What You Want
#
#                                artist_id        artist_names  \
# 0  spotify:artist:6dYrdRlNZSKaVxYg5IrvCH             The KLF
# 1  spotify:artist:0TnOYISbd1XYRBk9myaseg             Pitbull
# 2  spotify:artist:26dSoYclwsYLMAKD3tpOr4      Britney Spears
# 3  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E           The Kinks
# 4  spotify:artist:22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
#
#                  album_id                                         album_name  \
# 0  4MC0ZjNtVP1nDD5lsLxFjc                                   Songs Collection
# 1  5xLAcbvbSAlRtPXnKkggXA                     Pitbull Starring In Rebelution
# 2  3WNxdumkSMGMJRhEgK80qx     ...Baby One More Time (Digital Deluxe Version)
# 3  6lL6HugNEN4Vlc8sj0Zcse  Lola vs. Powerman and the Moneygoround, Pt. On...
# 4  0c78nsgqX6VfniSNWIxwoD                                       Let It Bleed
#
#           album_artist_id  album_artist_names album_release_date  \
# 0  6dYrdRlNZSKaVxYg5IrvCH             The KLF         1992-08-03
# 1  0TnOYISbd1XYRBk9myaseg             Pitbull         2009-10-23
# 2  26dSoYclwsYLMAKD3tpOr4      Britney Spears         1999-01-12
# 3  1SQRv42e4PjEYfPhS0Tk9E           The Kinks         2014-10-20
# 4  22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones         1969-12-05
#
#                                      album_image_url  ...  key  loudness  \
# 0  https://i.scdn.co/image/ab67616d0000b27355346b...  ...  8.0   -12.305
# 1  https://i.scdn.co/image/ab67616d0000b27326d73a...  ...  2.0    -5.995
# 2  https://i.scdn.co/image/ab67616d0000b2738e4986...  ...  7.0    -5.171
# 3  https://i.scdn.co/image/ab67616d0000b2731e7c53...  ...  9.0    -8.920
# 4  https://i.scdn.co/image/ab67616d0000b27373d927...  ...  0.0    -9.611
#
#    mode  speechiness  acousticness instrumentalness liveness  valence  \
# 0   1.0       0.0480        0.0158         0.112000   0.4080    0.504
# 1   1.0       0.1490        0.0142         0.000021   0.2370    0.800
# 2   1.0       0.0305        0.5600         0.000001   0.3380    0.706
# 3   1.0       0.2590        0.5680         0.000051   0.0384    0.833
# 4   1.0       0.0687        0.6750         0.000073   0.2890    0.497
#
#      tempo  time_signature
# 0  111.458             4.0
# 1  127.045             4.0
# 2   74.981             4.0
# 3   75.311             4.0
# 4   85.818             4.0
#
# [5 rows x 29 columns]

# %%
for i in df['artist_id']:
    if i != '':
        df['artist_id'] = df['artist_id'].str.replace('spotify:artist:', '', regex=False)
        df['artist_id'] = df['artist_id'].str.replace(' ', '', regex=False)

df.head()
# Out:
#                  track_id                               track_name  \
# 0  1XAZlnVtthcDZt2NI1Dtxo  Justified & Ancient - Stand by the Jams
# 1  6a8GbQIlV8HBUW3c6Uk9PH          I Know You Want Me (Calle Ocho)
# 2  70XtWbcVZcpaOddJftMcVi       From the Bottom of My Broken Heart
# 3  1NXUWyPJk5kO6DQJ5t7bDu         Apeman - 2014 Remastered Version
# 4  72WZtWs6V7uu3aMgMmEkYe       You Can't Always Get What You Want
#
#                 artist_id        artist_names                album_id  \
# 0  6dYrdRlNZSKaVxYg5IrvCH             The KLF  4MC0ZjNtVP1nDD5lsLxFjc
# 1  0TnOYISbd1XYRBk9myaseg             Pitbull  5xLAcbvbSAlRtPXnKkggXA
# 2  26dSoYclwsYLMAKD3tpOr4      Britney Spears  3WNxdumkSMGMJRhEgK80qx
# 3  1SQRv42e4PjEYfPhS0Tk9E           The Kinks  6lL6HugNEN4Vlc8sj0Zcse
# 4  22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones  0c78nsgqX6VfniSNWIxwoD
#
#                                           album_name         album_artist_id  \
# 0                                   Songs Collection  6dYrdRlNZSKaVxYg5IrvCH
# 1                     Pitbull Starring In Rebelution  0TnOYISbd1XYRBk9myaseg
# 2     ...Baby One More Time (Digital Deluxe Version)  26dSoYclwsYLMAKD3tpOr4
# 3  Lola vs. Powerman and the Moneygoround, Pt. On...  1SQRv42e4PjEYfPhS0Tk9E
# 4                                       Let It Bleed  22bE4uQ6baNwSHPVcDxLCe
#
#    album_artist_names album_release_date  \
# 0             The KLF         1992-08-03
# 1             Pitbull         2009-10-23
# 2      Britney Spears         1999-01-12
# 3           The Kinks         2014-10-20
# 4  The Rolling Stones         1969-12-05
#
#                                      album_image_url  ...  loudness  mode  \
# 0  https://i.scdn.co/image/ab67616d0000b27355346b...  ...   -12.305   1.0
# 1  https://i.scdn.co/image/ab67616d0000b27326d73a...  ...    -5.995   1.0
# 2  https://i.scdn.co/image/ab67616d0000b2738e4986...  ...    -5.171   1.0
# 3  https://i.scdn.co/image/ab67616d0000b2731e7c53...  ...    -8.920   1.0
# 4  https://i.scdn.co/image/ab67616d0000b27373d927...  ...    -9.611   1.0
#
#    speechiness  acousticness  instrumentalness liveness valence    tempo  \
# 0       0.0480        0.0158          0.112000   0.4080   0.504  111.458
# 1       0.1490        0.0142          0.000021   0.2370   0.800  127.045
# 2       0.0305        0.5600          0.000001   0.3380   0.706   74.981
# 3       0.2590        0.5680          0.000051   0.0384   0.833   75.311
# 4       0.0687        0.6750          0.000073   0.2890   0.497   85.818
#
#    time_signature                                label
# 0             4.0                  Jams Communications
# 1             4.0  Mr.305/Polo Grounds Music/J Records
# 2             4.0                                 Jive
# 3             4.0                    Sanctuary Records
# 4             4.0                Universal Music Group
#
# [5 rows x 30 columns]

# %%
df.head(10)
# Out:
#                  track_id                                         track_name  \
# 0  1XAZlnVtthcDZt2NI1Dtxo            Justified & Ancient - Stand by the Jams
# 1  6a8GbQIlV8HBUW3c6Uk9PH                    I Know You Want Me (Calle Ocho)
# 2  70XtWbcVZcpaOddJftMcVi                 From the Bottom of My Broken Heart
# 3  1NXUWyPJk5kO6DQJ5t7bDu                   Apeman - 2014 Remastered Version
# 4  72WZtWs6V7uu3aMgMmEkYe                 You Can't Always Get What You Want
# 5  4bEb3KE4mSKlTFjtWJQBqO                         Don't Stop - 2004 Remaster
# 6  0d2iYfpKoM0QCKvcLCkBao                    Eastside (with Halsey & Khalid)
# 7  5LjSxAIKwyZvQqJ04ZQ0Da  Something About The Way You Look Tonight - Edi...
# 8  00qOE7OjRl0BpYiCiweZB2                                      Juke Box Hero
# 9  3OalxlWH0v14kyBcNBMINt                                              Mercy
#
#                                            artist_id  \
# 0              spotify:artist:6dYrdRlNZSKaVxYg5IrvCH
# 1              spotify:artist:0TnOYISbd1XYRBk9myaseg
# 2              spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 3              spotify:artist:1SQRv42e4PjEYfPhS0Tk9E
# 4              spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# 5              spotify:artist:08GQAI4eElDnROBrJRGE0X
# 6  spotify:artist:5CiGnKThu5ctn9pBxv7DGa, spotify...
# 7              spotify:artist:3PhoLpVuITZKcymswpck5b
# 8              spotify:artist:6IRouO5mvvfcyxtPDKMYFN
# 9              spotify:artist:7n2wHs1TKAczGzO7Dd2rGr
#
#                    artist_names                album_id  \
# 0                       The KLF  4MC0ZjNtVP1nDD5lsLxFjc
# 1                       Pitbull  5xLAcbvbSAlRtPXnKkggXA
# 2                Britney Spears  3WNxdumkSMGMJRhEgK80qx
# 3                     The Kinks  6lL6HugNEN4Vlc8sj0Zcse
# 4            The Rolling Stones  0c78nsgqX6VfniSNWIxwoD
# 5                 Fleetwood Mac  1bt6q2SruMsBtcerNVtpZB
# 6  benny blanco, Halsey, Khalid  7pkLXlFdpQDfmHujT2AbBK
# 7                    Elton John  3g61rwvRs1NPeVBxuAMmHZ
# 8                     Foreigner  2Pw51hAGvWpTA3AYl2WVuu
# 9                  Shawn Mendes  0S9QJQiRmG9JYYfJfKqhDF
#
#                                           album_name  \
# 0                                   Songs Collection
# 1                     Pitbull Starring In Rebelution
# 2     ...Baby One More Time (Digital Deluxe Version)
# 3  Lola vs. Powerman and the Moneygoround, Pt. On...
# 4                                       Let It Bleed
# 5                                            Rumours
# 6                    Eastside (with Halsey & Khalid)
# 7      Candle In The Wind 1997 / Something About ...
# 8                                       4 (Expanded)
# 9                                Illuminate (Deluxe)
#
#                                      album_artist_id  \
# 0                             6dYrdRlNZSKaVxYg5IrvCH
# 1                             0TnOYISbd1XYRBk9myaseg
# 2                             26dSoYclwsYLMAKD3tpOr4
# 3                             1SQRv42e4PjEYfPhS0Tk9E
# 4                             22bE4uQ6baNwSHPVcDxLCe
# 5                             08GQAI4eElDnROBrJRGE0X
# 6  5CiGnKThu5ctn9pBxv7DGa, 26VFTg2z8YR0cCuwLzESi2...
# 7                             3PhoLpVuITZKcymswpck5b
# 8                             6IRouO5mvvfcyxtPDKMYFN
# 9                             7n2wHs1TKAczGzO7Dd2rGr
#
#              album_artist_names album_release_date  \
# 0                       The KLF         1992-08-03
# 1                       Pitbull         2009-10-23
# 2                Britney Spears         1999-01-12
# 3                     The Kinks         2014-10-20
# 4            The Rolling Stones         1969-12-05
# 5                 Fleetwood Mac         1977-02-04
# 6  benny blanco, Halsey, Khalid         2018-07-12
# 7                    Elton John         1997-01-01
# 8                     Foreigner               1981
# 9                  Shawn Mendes         2016-09-23
#
#                                      album_image_url  ...   key  loudness  \
# 0  https://i.scdn.co/image/ab67616d0000b27355346b...  ...   8.0   -12.305
# 1  https://i.scdn.co/image/ab67616d0000b27326d73a...  ...   2.0    -5.995
# 2  https://i.scdn.co/image/ab67616d0000b2738e4986...  ...   7.0    -5.171
# 3  https://i.scdn.co/image/ab67616d0000b2731e7c53...  ...   9.0    -8.920
# 4  https://i.scdn.co/image/ab67616d0000b27373d927...  ...   0.0    -9.611
# 5  https://i.scdn.co/image/ab67616d0000b27357df7c...  ...   9.0    -7.724
# 6  https://i.scdn.co/image/ab67616d0000b2733154f0...  ...   6.0    -7.648
# 7  https://i.scdn.co/image/ab67616d0000b27352a56d...  ...   6.0    -7.643
# 8  https://i.scdn.co/image/ab67616d0000b27362d48a...  ...   9.0    -5.554
# 9  https://i.scdn.co/image/ab67616d0000b2738a24ed...  ...  11.0    -4.934
#
#    mode  speechiness  acousticness instrumentalness liveness  valence  \
# 0   1.0       0.0480        0.0158         0.112000   0.4080    0.504
# 1   1.0       0.1490        0.0142         0.000021   0.2370    0.800
# 2   1.0       0.0305        0.5600         0.000001   0.3380    0.706
# 3   1.0       0.2590        0.5680         0.000051   0.0384    0.833
# 4   1.0       0.0687        0.6750         0.000073   0.2890    0.497
# 5   1.0       0.0356        0.0393         0.000011   0.0387    0.834
# 6   0.0       0.3210        0.5550         0.000000   0.1160    0.319
# 7   1.0       0.0262        0.1740         0.000033   0.0753    0.541
# 8   1.0       0.0654        0.0828         0.000000   0.0844    0.522
# 9   0.0       0.0871        0.1130         0.000000   0.1100    0.357
#
#      tempo  time_signature
# 0  111.458             4.0
# 1  127.045             4.0
# 2   74.981             4.0
# 3   75.311             4.0
# 4   85.818             4.0
# 5  118.745             4.0
# 6   89.391             4.0
# 7  143.412             4.0
# 8  176.647             4.0
# 9  148.064             4.0
#
# [10 rows x 29 columns]

# %%
df1 = df.dropna(subset=['track_id', 'track_name', 'artist_id', 'artist_names', 'album_release_date', 'album_id','album_name', 'album_artist_id','album_artist_names', 'album_image_url'])

# %%
df1.head(10)
# Out:
#                  track_id                                         track_name  \
# 0  1XAZlnVtthcDZt2NI1Dtxo            Justified & Ancient - Stand by the Jams
# 1  6a8GbQIlV8HBUW3c6Uk9PH                    I Know You Want Me (Calle Ocho)
# 2  70XtWbcVZcpaOddJftMcVi                 From the Bottom of My Broken Heart
# 3  1NXUWyPJk5kO6DQJ5t7bDu                   Apeman - 2014 Remastered Version
# 4  72WZtWs6V7uu3aMgMmEkYe                 You Can't Always Get What You Want
# 5  4bEb3KE4mSKlTFjtWJQBqO                         Don't Stop - 2004 Remaster
# 6  0d2iYfpKoM0QCKvcLCkBao                    Eastside (with Halsey & Khalid)
# 7  5LjSxAIKwyZvQqJ04ZQ0Da  Something About The Way You Look Tonight - Edi...
# 8  00qOE7OjRl0BpYiCiweZB2                                      Juke Box Hero
# 9  3OalxlWH0v14kyBcNBMINt                                              Mercy
#
#                                            artist_id  \
# 0              spotify:artist:6dYrdRlNZSKaVxYg5IrvCH
# 1              spotify:artist:0TnOYISbd1XYRBk9myaseg
# 2              spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 3              spotify:artist:1SQRv42e4PjEYfPhS0Tk9E
# 4              spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# 5              spotify:artist:08GQAI4eElDnROBrJRGE0X
# 6  spotify:artist:5CiGnKThu5ctn9pBxv7DGa, spotify...
# 7              spotify:artist:3PhoLpVuITZKcymswpck5b
# 8              spotify:artist:6IRouO5mvvfcyxtPDKMYFN
# 9              spotify:artist:7n2wHs1TKAczGzO7Dd2rGr
#
#                    artist_names                album_id  \
# 0                       The KLF  4MC0ZjNtVP1nDD5lsLxFjc
# 1                       Pitbull  5xLAcbvbSAlRtPXnKkggXA
# 2                Britney Spears  3WNxdumkSMGMJRhEgK80qx
# 3                     The Kinks  6lL6HugNEN4Vlc8sj0Zcse
# 4            The Rolling Stones  0c78nsgqX6VfniSNWIxwoD
# 5                 Fleetwood Mac  1bt6q2SruMsBtcerNVtpZB
# 6  benny blanco, Halsey, Khalid  7pkLXlFdpQDfmHujT2AbBK
# 7                    Elton John  3g61rwvRs1NPeVBxuAMmHZ
# 8                     Foreigner  2Pw51hAGvWpTA3AYl2WVuu
# 9                  Shawn Mendes  0S9QJQiRmG9JYYfJfKqhDF
#
#                                           album_name  \
# 0                                   Songs Collection
# 1                     Pitbull Starring In Rebelution
# 2     ...Baby One More Time (Digital Deluxe Version)
# 3  Lola vs. Powerman and the Moneygoround, Pt. On...
# 4                                       Let It Bleed
# 5                                            Rumours
# 6                    Eastside (with Halsey & Khalid)
# 7      Candle In The Wind 1997 / Something About ...
# 8                                       4 (Expanded)
# 9                                Illuminate (Deluxe)
#
#                                      album_artist_id  \
# 0                             6dYrdRlNZSKaVxYg5IrvCH
# 1                             0TnOYISbd1XYRBk9myaseg
# 2                             26dSoYclwsYLMAKD3tpOr4
# 3                             1SQRv42e4PjEYfPhS0Tk9E
# 4                             22bE4uQ6baNwSHPVcDxLCe
# 5                             08GQAI4eElDnROBrJRGE0X
# 6  5CiGnKThu5ctn9pBxv7DGa, 26VFTg2z8YR0cCuwLzESi2...
# 7                             3PhoLpVuITZKcymswpck5b
# 8                             6IRouO5mvvfcyxtPDKMYFN
# 9                             7n2wHs1TKAczGzO7Dd2rGr
#
#              album_artist_names album_release_date  \
# 0                       The KLF         1992-08-03
# 1                       Pitbull         2009-10-23
# 2                Britney Spears         1999-01-12
# 3                     The Kinks         2014-10-20
# 4            The Rolling Stones         1969-12-05
# 5                 Fleetwood Mac         1977-02-04
# 6  benny blanco, Halsey, Khalid         2018-07-12
# 7                    Elton John         1997-01-01
# 8                     Foreigner               1981
# 9                  Shawn Mendes         2016-09-23
#
#                                      album_image_url  ...   key  loudness  \
# 0  https://i.scdn.co/image/ab67616d0000b27355346b...  ...   8.0   -12.305
# 1  https://i.scdn.co/image/ab67616d0000b27326d73a...  ...   2.0    -5.995
# 2  https://i.scdn.co/image/ab67616d0000b2738e4986...  ...   7.0    -5.171
# 3  https://i.scdn.co/image/ab67616d0000b2731e7c53...  ...   9.0    -8.920
# 4  https://i.scdn.co/image/ab67616d0000b27373d927...  ...   0.0    -9.611
# 5  https://i.scdn.co/image/ab67616d0000b27357df7c...  ...   9.0    -7.724
# 6  https://i.scdn.co/image/ab67616d0000b2733154f0...  ...   6.0    -7.648
# 7  https://i.scdn.co/image/ab67616d0000b27352a56d...  ...   6.0    -7.643
# 8  https://i.scdn.co/image/ab67616d0000b27362d48a...  ...   9.0    -5.554
# 9  https://i.scdn.co/image/ab67616d0000b2738a24ed...  ...  11.0    -4.934
#
#    mode  speechiness  acousticness instrumentalness liveness  valence  \
# 0   1.0       0.0480        0.0158         0.112000   0.4080    0.504
# 1   1.0       0.1490        0.0142         0.000021   0.2370    0.800
# 2   1.0       0.0305        0.5600         0.000001   0.3380    0.706
# 3   1.0       0.2590        0.5680         0.000051   0.0384    0.833
# 4   1.0       0.0687        0.6750         0.000073   0.2890    0.497
# 5   1.0       0.0356        0.0393         0.000011   0.0387    0.834
# 6   0.0       0.3210        0.5550         0.000000   0.1160    0.319
# 7   1.0       0.0262        0.1740         0.000033   0.0753    0.541
# 8   1.0       0.0654        0.0828         0.000000   0.0844    0.522
# 9   0.0       0.0871        0.1130         0.000000   0.1100    0.357
#
#      tempo  time_signature
# 0  111.458             4.0
# 1  127.045             4.0
# 2   74.981             4.0
# 3   75.311             4.0
# 4   85.818             4.0
# 5  118.745             4.0
# 6   89.391             4.0
# 7  143.412             4.0
# 8  176.647             4.0
# 9  148.064             4.0
#
# [10 rows x 29 columns]

# %%
def standardise_date(date_str):
    if pd.isna(date_str) or date_str == '':
        return pd.NaT

    formats = [
        '%Y/%m/%d', '%Y-%m-%d', '%d %b %Y', '%b %d, %Y', '%d %B %Y',
        '%d-%m-%Y', '%d/%m/%Y'
    ]
    for fmt in formats:
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            continue

    return pd.NaT

# %%
df1['album_release_date'] = (df1['album_release_date'].apply(standardise_date))
df1['album_release_date'] = (df1['album_release_date'].dt.strftime('%d/%m/%Y'))
# Out:
# C:\Users\ashle\AppData\Local\Temp\ipykernel_24144\328521417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['album_release_date'] = (df1['album_release_date'].apply(standardise_date))
# C:\Users\ashle\AppData\Local\Temp\ipykernel_24144\328521417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['album_release_date'] = (df1['album_release_date'].dt.strftime('%d/%m/%Y'))

# %%
df1.head()
# Out:
#                  track_id                               track_name  \
# 0  1XAZlnVtthcDZt2NI1Dtxo  Justified & Ancient - Stand by the Jams
# 1  6a8GbQIlV8HBUW3c6Uk9PH          I Know You Want Me (Calle Ocho)
# 2  70XtWbcVZcpaOddJftMcVi       From the Bottom of My Broken Heart
# 3  1NXUWyPJk5kO6DQJ5t7bDu         Apeman - 2014 Remastered Version
# 4  72WZtWs6V7uu3aMgMmEkYe       You Can't Always Get What You Want
#
#                                artist_id        artist_names  \
# 0  spotify:artist:6dYrdRlNZSKaVxYg5IrvCH             The KLF
# 1  spotify:artist:0TnOYISbd1XYRBk9myaseg             Pitbull
# 2  spotify:artist:26dSoYclwsYLMAKD3tpOr4      Britney Spears
# 3  spotify:artist:1SQRv42e4PjEYfPhS0Tk9E           The Kinks
# 4  spotify:artist:22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
#
#                  album_id                                         album_name  \
# 0  4MC0ZjNtVP1nDD5lsLxFjc                                   Songs Collection
# 1  5xLAcbvbSAlRtPXnKkggXA                     Pitbull Starring In Rebelution
# 2  3WNxdumkSMGMJRhEgK80qx     ...Baby One More Time (Digital Deluxe Version)
# 3  6lL6HugNEN4Vlc8sj0Zcse  Lola vs. Powerman and the Moneygoround, Pt. On...
# 4  0c78nsgqX6VfniSNWIxwoD                                       Let It Bleed
#
#           album_artist_id  album_artist_names album_release_date  \
# 0  6dYrdRlNZSKaVxYg5IrvCH             The KLF         03/08/1992
# 1  0TnOYISbd1XYRBk9myaseg             Pitbull         23/10/2009
# 2  26dSoYclwsYLMAKD3tpOr4      Britney Spears         12/01/1999
# 3  1SQRv42e4PjEYfPhS0Tk9E           The Kinks         20/10/2014
# 4  22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones         05/12/1969
#
#                                      album_image_url  ...  key  loudness  \
# 0  https://i.scdn.co/image/ab67616d0000b27355346b...  ...  8.0   -12.305
# 1  https://i.scdn.co/image/ab67616d0000b27326d73a...  ...  2.0    -5.995
# 2  https://i.scdn.co/image/ab67616d0000b2738e4986...  ...  7.0    -5.171
# 3  https://i.scdn.co/image/ab67616d0000b2731e7c53...  ...  9.0    -8.920
# 4  https://i.scdn.co/image/ab67616d0000b27373d927...  ...  0.0    -9.611
#
#    mode  speechiness  acousticness instrumentalness liveness  valence  \
# 0   1.0       0.0480        0.0158         0.112000   0.4080    0.504
# 1   1.0       0.1490        0.0142         0.000021   0.2370    0.800
# 2   1.0       0.0305        0.5600         0.000001   0.3380    0.706
# 3   1.0       0.2590        0.5680         0.000051   0.0384    0.833
# 4   1.0       0.0687        0.6750         0.000073   0.2890    0.497
#
#      tempo  time_signature
# 0  111.458             4.0
# 1  127.045             4.0
# 2   74.981             4.0
# 3   75.311             4.0
# 4   85.818             4.0
#
# [5 rows x 29 columns]

# %%
df1 = df1.dropna(subset=['album_release_date'])
df1.head(10)
# Out:
#                   track_id                                         track_name  \
# 0   1XAZlnVtthcDZt2NI1Dtxo            Justified & Ancient - Stand by the Jams
# 1   6a8GbQIlV8HBUW3c6Uk9PH                    I Know You Want Me (Calle Ocho)
# 2   70XtWbcVZcpaOddJftMcVi                 From the Bottom of My Broken Heart
# 3   1NXUWyPJk5kO6DQJ5t7bDu                   Apeman - 2014 Remastered Version
# 4   72WZtWs6V7uu3aMgMmEkYe                 You Can't Always Get What You Want
# 5   4bEb3KE4mSKlTFjtWJQBqO                         Don't Stop - 2004 Remaster
# 6   0d2iYfpKoM0QCKvcLCkBao                    Eastside (with Halsey & Khalid)
# 7   5LjSxAIKwyZvQqJ04ZQ0Da  Something About The Way You Look Tonight - Edi...
# 9   3OalxlWH0v14kyBcNBMINt                                              Mercy
# 10  0CtkjgZpkgnW7U6WmHsakD                                     It's Like That
#
#                                             artist_id  \
# 0               spotify:artist:6dYrdRlNZSKaVxYg5IrvCH
# 1               spotify:artist:0TnOYISbd1XYRBk9myaseg
# 2               spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 3               spotify:artist:1SQRv42e4PjEYfPhS0Tk9E
# 4               spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# 5               spotify:artist:08GQAI4eElDnROBrJRGE0X
# 6   spotify:artist:5CiGnKThu5ctn9pBxv7DGa, spotify...
# 7               spotify:artist:3PhoLpVuITZKcymswpck5b
# 9               spotify:artist:7n2wHs1TKAczGzO7Dd2rGr
# 10  spotify:artist:3CQIn7N5CuRDP8wEI7FiDA, spotify...
#
#                     artist_names                album_id  \
# 0                        The KLF  4MC0ZjNtVP1nDD5lsLxFjc
# 1                        Pitbull  5xLAcbvbSAlRtPXnKkggXA
# 2                 Britney Spears  3WNxdumkSMGMJRhEgK80qx
# 3                      The Kinks  6lL6HugNEN4Vlc8sj0Zcse
# 4             The Rolling Stones  0c78nsgqX6VfniSNWIxwoD
# 5                  Fleetwood Mac  1bt6q2SruMsBtcerNVtpZB
# 6   benny blanco, Halsey, Khalid  7pkLXlFdpQDfmHujT2AbBK
# 7                     Elton John  3g61rwvRs1NPeVBxuAMmHZ
# 9                   Shawn Mendes  0S9QJQiRmG9JYYfJfKqhDF
# 10      Run–D.M.C., Jason Nevins  3bRdFxQZdU5g6VjLq8KaU7
#
#                                            album_name  \
# 0                                    Songs Collection
# 1                      Pitbull Starring In Rebelution
# 2      ...Baby One More Time (Digital Deluxe Version)
# 3   Lola vs. Powerman and the Moneygoround, Pt. On...
# 4                                        Let It Bleed
# 5                                             Rumours
# 6                     Eastside (with Halsey & Khalid)
# 7       Candle In The Wind 1997 / Something About ...
# 9                                 Illuminate (Deluxe)
# 10                                  The Greatest Hits
#
#                                       album_artist_id  \
# 0                              6dYrdRlNZSKaVxYg5IrvCH
# 1                              0TnOYISbd1XYRBk9myaseg
# 2                              26dSoYclwsYLMAKD3tpOr4
# 3                              1SQRv42e4PjEYfPhS0Tk9E
# 4                              22bE4uQ6baNwSHPVcDxLCe
# 5                              08GQAI4eElDnROBrJRGE0X
# 6   5CiGnKThu5ctn9pBxv7DGa, 26VFTg2z8YR0cCuwLzESi2...
# 7                              3PhoLpVuITZKcymswpck5b
# 9                              7n2wHs1TKAczGzO7Dd2rGr
# 10                             3CQIn7N5CuRDP8wEI7FiDA
#
#               album_artist_names album_release_date  \
# 0                        The KLF         03/08/1992
# 1                        Pitbull         23/10/2009
# 2                 Britney Spears         12/01/1999
# 3                      The Kinks         20/10/2014
# 4             The Rolling Stones         05/12/1969
# 5                  Fleetwood Mac         04/02/1977
# 6   benny blanco, Halsey, Khalid         12/07/2018
# 7                     Elton John         01/01/1997
# 9                   Shawn Mendes         23/09/2016
# 10                    Run–D.M.C.         10/09/2002
#
#                                       album_image_url  ...   key  loudness  \
# 0   https://i.scdn.co/image/ab67616d0000b27355346b...  ...   8.0   -12.305
# 1   https://i.scdn.co/image/ab67616d0000b27326d73a...  ...   2.0    -5.995
# 2   https://i.scdn.co/image/ab67616d0000b2738e4986...  ...   7.0    -5.171
# 3   https://i.scdn.co/image/ab67616d0000b2731e7c53...  ...   9.0    -8.920
# 4   https://i.scdn.co/image/ab67616d0000b27373d927...  ...   0.0    -9.611
# 5   https://i.scdn.co/image/ab67616d0000b27357df7c...  ...   9.0    -7.724
# 6   https://i.scdn.co/image/ab67616d0000b2733154f0...  ...   6.0    -7.648
# 7   https://i.scdn.co/image/ab67616d0000b27352a56d...  ...   6.0    -7.643
# 9   https://i.scdn.co/image/ab67616d0000b2738a24ed...  ...  11.0    -4.934
# 10  https://i.scdn.co/image/ab67616d0000b273a4ad28...  ...   7.0   -11.208
#
#     mode  speechiness  acousticness instrumentalness liveness  valence  \
# 0    1.0       0.0480        0.0158         0.112000   0.4080    0.504
# 1    1.0       0.1490        0.0142         0.000021   0.2370    0.800
# 2    1.0       0.0305        0.5600         0.000001   0.3380    0.706
# 3    1.0       0.2590        0.5680         0.000051   0.0384    0.833
# 4    1.0       0.0687        0.6750         0.000073   0.2890    0.497
# 5    1.0       0.0356        0.0393         0.000011   0.0387    0.834
# 6    0.0       0.3210        0.5550         0.000000   0.1160    0.319
# 7    1.0       0.0262        0.1740         0.000033   0.0753    0.541
# 9    0.0       0.0871        0.1130         0.000000   0.1100    0.357
# 10   1.0       0.0427        0.0168         0.450000   0.1330    0.666
#
#       tempo  time_signature
# 0   111.458             4.0
# 1   127.045             4.0
# 2    74.981             4.0
# 3    75.311             4.0
# 4    85.818             4.0
# 5   118.745             4.0
# 6    89.391             4.0
# 7   143.412             4.0
# 9   148.064             4.0
# 10  129.029             4.0
#
# [10 rows x 29 columns]

# %%
import requests
import base64


def AuthenticateSpotify():
    """Authenticate with Spotify API and get an access token."""

    # Spotify client credentials
    client_id = "47f30520c4e8485b925d9910d6d68d62"
    client_secret = "aa86334039704df3aec915153c9dd8c4"

    # Encode client_id and client_secret in Base64
    auth_header = base64.b64encode(f"{client_id}:{client_secret}".encode()).decode()

    # Define the request headers and data
    headers = {
        "Authorization": f"Basic {auth_header}",
        "Content-Type": "application/x-www-form-urlencoded",
    }
    data = {
        "grant_type": "client_credentials",
    }

    try:
        # Make the POST request to get the access token
        response = requests.post("https://accounts.spotify.com/api/token",
                                 headers=headers, data=data)
    except requests.exceptions.RequestException as e:
        raise f"Error: {e}"

    access_token = response.json().get("access_token")
    return access_token

import requests


def get_track_data(token, track_id):

    url = f'https://api.spotify.com/v1/tracks/{track_id}'

    headers = {
        "Authorization": f"Bearer {token}",
    }
    params = {
        "market": "ES",
    }
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        raise f'Error:, {response.status_code, response.json()}'
    
def get_tracks_data(token, track_ids):
    ids = ','.join(track_ids)

    url = f'https://api.spotify.com/v1/tracks?ids={ids}'

    headers = {
        "Authorization": f"Bearer {token}",
    }
    params = {
        "market": "ES",
    }
    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        raise f'Error:, {response.status_code, response.json()}'

# %%
a = get_track_data(AuthenticateSpotify(), df1['track_id'][0])
df2 = df1.copy()
a.get('external_ids')['isrc']
try:
    if a.get('external_ids')['isrc'] == df2.loc[0, 'isrc']:
        df2.loc[0, 'popularity'] = a['popularity']
except Exception as e:
    print(f"Error processing track ID {0}: {e}")

# %%
token = AuthenticateSpotify()

df2 = df1.copy()
batch_size = 50  # Adjust batch size if needed

for i in range(0, len(df1), batch_size):
    start_index = i
    end_index = min(i + batch_size, len(df1))
    track_ids = df1.iloc[start_index:end_index]['track_id'].tolist()

    try:
        # Call the get_track_popularity function for the batch
        response = get_tracks_data(token, track_ids)
        temp_isrc = [item.get('external_ids')['isrc'] for item in response['tracks']]
        temp_pop = [item['popularity'] for item in response['tracks']]
        # Create a mapping of ISRC to popularity
        isrc_popularity_map = dict(zip(temp_isrc, temp_pop))

        # Update the popularity column in df2 only if ISRC matches
        for idx in df1.iloc[i:end_index].index:
            try:
                isrc_value = df1.loc[idx, 'isrc']
                if isrc_value in isrc_popularity_map:
                    df2.loc[idx, 'popularity'] = isrc_popularity_map[isrc_value]
                else:
                    df2.loc[idx, 'popularity'] = pd.NA  # Set as null if ISRC doesn't match
            except Exception as row_error:
                print(f"Error processing row {idx}: {row_error}")
                df2.loc[idx, 'popularity'] = pd.NA  # Set as null for problematic rows

    except Exception as batch_error:
        for j in range(start_index, end_index):
            try:
                ind = df2.iloc[j].index
                # Attempt to process each track ID individually
                track_id = df1.loc[ind, 'track_id']
                a = get_track_data(token, track_id)
                if 'isrc' in a.get('external_ids'):
                    isrc_value = a.get('external_ids')['isrc']
                    if isrc_value == df2.loc[ind, 'isrc']:
                        df2.loc[j, 'popularity'] = a['popularity']
                else:
                    print(f"ISRC not found for track ID {j}, irsc {df2.loc[ind, 'isrc']}")
            except Exception as e:
                print(f"Error processing track ID {j}, irsc {df2.loc[ind, 'isrc']}: {e}")
                # Optionally, handle the error or log it
        print(f"Error processing batch {i}-{end_index}: {batch_error}")
        print(f"Track IDs in batch: {track_ids}")
        # Optionally, continue to the next batch or break
        continue

print("Batch processing completed.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 14
#      13 response = get_tracks_data(token, track_ids)
# ---> 14 temp_isrc = [item.get('external_ids')['isrc'] for item in response['tracks']]
#      15 temp_pop = [item['popularity'] for item in response['tracks']]
#
# KeyError: 'isrc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 36
#      35 # Attempt to process each track ID individually
# ---> 36 track_id = df1.loc[ind, 'track_id']
#      37 a = get_track_data(token, track_id)
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1089, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1088         # This is an elided recursive call to iloc/loc
# -> 1089         return getattr(section, self.name)[new_key]
#    1091 raise IndexingError("not applicable")
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6248 if nmissing == len(indexer):
# -> 6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['track_id', 'track_name', 'artist_id', 'artist_names', 'album_id',\n       'album_name', 'album_artist_id', 'album_artist_names',\n       'album_release_date', 'album_image_url', 'disc_number', 'track_number',\n       'track_duration_ms', 'explicit', 'popularity', 'isrc', 'artist_genres',\n       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',\n       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',\n       'time_signature'],\n      dtype='object')] are in the [index]"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 45
#      43             print(f"ISRC not found for track ID {j}, irsc {df2.loc[ind, 'isrc']}")
#      44     except Exception as e:
# ---> 45         print(f"Error processing track ID {j}, irsc {df2.loc[ind, 'isrc']}: {e}")
#      46         # Optionally, handle the error or log it
#      47 print(f"Error processing batch {i}-{end_index}: {batch_error}")
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1089, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1087             return section
#    1088         # This is an elided recursive call to iloc/loc
# -> 1089         return getattr(section, self.name)[new_key]
#    1091 raise IndexingError("not applicable")
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\ashle\Documents\GitHub\DF_capstone\.venv\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['track_id', 'track_name', 'artist_id', 'artist_names', 'album_id',\n       'album_name', 'album_artist_id', 'album_artist_names',\n       'album_release_date', 'album_image_url', 'disc_number', 'track_number',\n       'track_duration_ms', 'explicit', 'popularity', 'isrc', 'artist_genres',\n       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',\n       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',\n       'time_signature'],\n      dtype='object')] are in the [index]"

# %%
print(get_track_data(AuthenticateSpotify(), df1['track_id'][8306]))
# Out:
# {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/02A3cEvlLLCbIMVDrK2GHV'}, 'href': 'https://api.spotify.com/v1/artists/02A3cEvlLLCbIMVDrK2GHV', 'id': '02A3cEvlLLCbIMVDrK2GHV', 'name': 'Starley', 'type': 'artist', 'uri': 'spotify:artist:02A3cEvlLLCbIMVDrK2GHV'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/3eAJ6Fh2OdrX6gcDgnByT2'}, 'href': 'https://api.spotify.com/v1/albums/3eAJ6Fh2OdrX6gcDgnByT2', 'id': '3eAJ6Fh2OdrX6gcDgnByT2', 'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273ecedec68b07c241fb586c843', 'width': 640, 'height': 640}, {'url': 'https://i.scdn.co/image/ab67616d00001e02ecedec68b07c241fb586c843', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d00004851ecedec68b07c241fb586c843', 'width': 64, 'height': 64}], 'is_playable': True, 'name': 'Touch Me', 'release_date': '2017-06-09', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:3eAJ6Fh2OdrX6gcDgnByT2'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/02A3cEvlLLCbIMVDrK2GHV'}, 'href': 'https://api.spotify.com/v1/artists/02A3cEvlLLCbIMVDrK2GHV', 'id': '02A3cEvlLLCbIMVDrK2GHV', 'name': 'Starley', 'type': 'artist', 'uri': 'spotify:artist:02A3cEvlLLCbIMVDrK2GHV'}], 'disc_number': 1, 'duration_ms': 208920, 'explicit': False, 'external_ids': {'isrc': 'AUCN31709919'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/2ZQthRFshRud0V6P9Abmop'}, 'href': 'https://api.spotify.com/v1/tracks/2ZQthRFshRud0V6P9Abmop', 'id': '1TLUzKFEOrDrRimptqKCfN', 'is_local': False, 'is_playable': True, 'name': 'Touch Me', 'popularity': 0, 'preview_url': None, 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:1TLUzKFEOrDrRimptqKCfN', 'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2ZQthRFshRud0V6P9Abmop'}, 'href': 'https://api.spotify.com/v1/tracks/2ZQthRFshRud0V6P9Abmop', 'id': '2ZQthRFshRud0V6P9Abmop', 'type': 'track', 'uri': 'spotify:track:2ZQthRFshRud0V6P9Abmop'}}

# %%
token = AuthenticateSpotify()

df1.reset_index(drop=True, inplace=True)

df2 = df1.copy()

def update_popularities(dataframe, token):

    updated_df = dataframe.copy()
    batch_size = 50  # Adjust batch size if needed

    for i in range(0, len(dataframe), batch_size):
        end_index = min(i + batch_size, len(dataframe))
        tracks_ids = dataframe[i:end_index]['track_id'].tolist()
        try:
            
            response = get_tracks_data(token, tracks_ids)
            temp_isrc = [item.get('external_ids')['isrc'] for item in response['tracks']]
            temp_pop = [item['popularity'] for item in response['tracks']]
            # Create a mapping of ISRC to popularity
            isrc_popularity_map = dict(zip(temp_isrc, temp_pop))
            
            # Update the popularity column in df2 only if ISRC matches
            for idx in dataframe[i:end_index].index:
                try:
                    isrc_value = dataframe.loc[idx, 'isrc']
                    if isrc_value in isrc_popularity_map:
                        updated_df.loc[idx, 'popularity'] = isrc_popularity_map[isrc_value]
                    else:
                        updated_df.loc[idx, 'popularity'] = pd.NA  # Set as null if ISRC doesn't match
                except Exception as row_error:
                    print(f"Error processing row {idx}: {row_error}")
                    updated_df.loc[idx, 'popularity'] = pd.NA  # Set as null for problematic rows
        except Exception as batch_error:
            for j in range(i, end_index):
                try:
                    # Attempt to process each track ID individually
                    track_id = dataframe.loc[j, 'track_id']
                    a = get_track_data(token, track_id)
                    if 'isrc' in a.get('external_ids'):
                        isrc_value = a.get('external_ids')['isrc']
                        if isrc_value == updated_df.loc[j, 'isrc']:
                            updated_df.loc[j, 'popularity'] = a['popularity']
                    else:
                        updated_df.loc[j, 'popularity'] = None
                        print(f"ISRC not found for track ID {j}, irsc {updated_df.loc[j, 'isrc']}")
                except Exception as e:
                    print(f"Error processing track ID {j}, irsc {updated_df.loc[j, 'isrc']}: {e}")
                    continue
                    # Optionally, handle the error or log it
            print(f"Error processing batch {i}-{end_index}: {batch_error}")
            print(f"Track IDs in batch: {track_ids}")
            # Optionally, continue to the next batch or break
            continue
    return updated_df

# Update the popularity values in df2r  emebr to drop null values
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# ISRC not found for track ID 8327, irsc USUM71310271
# Error processing batch 8300-8350: 'isrc'
# Track IDs in batch: ['0aldkB7GXVA9EnVqJKVKz3', '014J7jX1wSv0manSdRnveo', '4ReVjXSiFM92lmjAncPtZW', '0m7dJ7cibvW774OP5GbWHB', '6ThZMk79exIUyB7JIbbOH9', '0tUVnDB0pM7xYGGgIKnyVf', '3y9zMGuxWS8xkpOxNPfiMZ', '6Lst3nF4McKOTLSLuTvLhw', '3hQ9KSM719y8RnkXpUius8', '63nVsCAdxu9OdeRhe58wiE', '77hjM9bMmgfTGJXv14UFmi', '1tMSsGhbQtMI4uPfUT2Mdo', '4I5bvu2KDsrCg0EWHIcvul', '74JdR9aXE6I74oS1BVRsvb', '6avxJ3kn6rkPE21X4fyg7q', '66hayvUbTotekKU3H4ta1f', '7N3PAbqfTjSEU1edb2tY8j', '3672j9qcUufXuGwVoXHaeK', '1JELW8hALjo9FDfCTrqIX1', '5PYQUBXc7NYeI1obMKSJK0', '7hR5toSPEgwFZ78jfHdANM', '3V0PeMg2mhbYRtk9bioAwF', '2Nz6aF1umHh5Et6I5H581L', '7eBIV7xripa8OJFuZKVKvk', '71zJRiAG1f817v9R9tYMvg', '7FC9Lng8iXU081lbigu8m8', '1A8OrMrc15qpXp5MuOfvG2', '1C79CxJdMHjk9RkwX04DRh', '6rLqjzGV5VMLDWEnuUqi8q', '3WdmbQIAPxB6FliVo3DsDC', '4Ypojjb7T5AW2IgkCAxmAO', '1Uc2Tg8eE2gFs9Cx2KRlTD', '14QNFD1T4rTlH4o6bV8pxy', '4bohbKYM5RjGsSzv1EsBed', '1k2ybm1oz7rVPchTKCgMMz', '2nXBu5Ra6LGrJJzXHHm0co', '4OeFQtRyT7vsLnRTv7t8YT', '3qxvIhgdd3k22ioRqmgamM', '4JiEyzf0Md7KEFFGWDDdCr', '0XzYcrLcZ7TFSS6sE1tZ2L', '0hxCRcTNxtMLZhL7yjV6Mw', '6wjY4ksLjCWU5D3lnNBAhy', '6SKwQghsR8AISlxhcwyA9R', '1f44RQK9175FmceEJmDMQq', '3xiVh7Be0tcpU8MBap62nm', '1IONKlRfi7XzoAAluK7p7r', '5pP3RGiUtFVZlWotyJb9Ei', '07cyeNU4ACaV9kjGg4pZyc', '3MOECVkNshqHYTPt5DZcdN', '0CnD7Hiw6pae6rLsZw5q5W']
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
#                     track_id  \
# 0     1XAZlnVtthcDZt2NI1Dtxo
# 1     6a8GbQIlV8HBUW3c6Uk9PH
# 2     70XtWbcVZcpaOddJftMcVi
# 3     1NXUWyPJk5kO6DQJ5t7bDu
# 4     72WZtWs6V7uu3aMgMmEkYe
# ...                      ...
# 8616  3kcKlOkQQEPVwxwljbGJ5p
# 8617  5k9QrzJFDAp5cXVdzAi02f
# 8618  5ydeCNaWDmFbu4zl0roPAH
# 8619  0zKbDrEXKpnExhGQRe9dxt
# 8620  3iKuIfvoU50eww6EVzNqHo
#
#                                              track_name  \
# 0               Justified & Ancient - Stand by the Jams
# 1                       I Know You Want Me (Calle Ocho)
# 2                    From the Bottom of My Broken Heart
# 3                      Apeman - 2014 Remastered Version
# 4                    You Can't Always Get What You Want
# ...                                                 ...
# 8616                       Kernkraft 400 (A Better Day)
# 8617                       Never Say Never - Radio Edit
# 8618  Groovejet (If This Ain't Love) [feat. Sophie E...
# 8619                                            Lay Low
# 8620                                        Padam Padam
#
#                                               artist_id  \
# 0                 spotify:artist:6dYrdRlNZSKaVxYg5IrvCH
# 1                 spotify:artist:0TnOYISbd1XYRBk9myaseg
# 2                 spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 3                 spotify:artist:1SQRv42e4PjEYfPhS0Tk9E
# 4                 spotify:artist:22bE4uQ6baNwSHPVcDxLCe
# ...                                                 ...
# 8616  spotify:artist:0u6GtibW46tFX7koQ6uNJZ, spotify...
# 8617              spotify:artist:1ScZSjoYAihNNm9qlhzDnL
# 8618  spotify:artist:4bmymFwDu9zLCiTRUmrewb, spotify...
# 8619              spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z
# 8620              spotify:artist:4RVnAU35WRWra6OZ3CbbMA
#
#                       artist_names                album_id  \
# 0                          The KLF  4MC0ZjNtVP1nDD5lsLxFjc
# 1                          Pitbull  5xLAcbvbSAlRtPXnKkggXA
# 2                   Britney Spears  3WNxdumkSMGMJRhEgK80qx
# 3                        The Kinks  6lL6HugNEN4Vlc8sj0Zcse
# 4               The Rolling Stones  0c78nsgqX6VfniSNWIxwoD
# ...                            ...                     ...
# 8616                    Topic, A7S  2NIChqkijGw4r4Dqfmg0A3
# 8617                     Vandalism  2n506u3HKN3CaEDvAjv5Ct
# 8618  Spiller, Sophie Ellis-Bextor  20Q3pGpYiyicF32x5L8ppH
# 8619                        Tiësto  0EYKSXXTsON8ZA95BuCoXn
# 8620                 Kylie Minogue  0OHc8STurn45gpk3dyIiw5
#
#                                              album_name  \
# 0                                      Songs Collection
# 1                        Pitbull Starring In Rebelution
# 2        ...Baby One More Time (Digital Deluxe Version)
# 3     Lola vs. Powerman and the Moneygoround, Pt. On...
# 4                                          Let It Bleed
# ...                                                 ...
# 8616                       Kernkraft 400 (A Better Day)
# 8617                                    Never Say Never
# 8618  Groovejet (If This Ain't Love) [feat. Sophie E...
# 8619                                            Lay Low
# 8620                                        Padam Padam
#
#                                      album_artist_id  album_artist_names  \
# 0                             6dYrdRlNZSKaVxYg5IrvCH             The KLF
# 1                             0TnOYISbd1XYRBk9myaseg             Pitbull
# 2                             26dSoYclwsYLMAKD3tpOr4      Britney Spears
# 3                             1SQRv42e4PjEYfPhS0Tk9E           The Kinks
# 4                             22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
# ...                                              ...                 ...
# 8616  0u6GtibW46tFX7koQ6uNJZ, 5Wg2b4Mp42gicxEeDNawf7          Topic, A7S
# 8617                          1ScZSjoYAihNNm9qlhzDnL           Vandalism
# 8618                          4bmymFwDu9zLCiTRUmrewb             Spiller
# 8619                          2o5jDhtHVPhrJdv3cEQ99Z              Tiësto
# 8620                          4RVnAU35WRWra6OZ3CbbMA       Kylie Minogue
#
#      album_release_date                                    album_image_url  \
# 0            03/08/1992  https://i.scdn.co/image/ab67616d0000b27355346b...
# 1            23/10/2009  https://i.scdn.co/image/ab67616d0000b27326d73a...
# 2            12/01/1999  https://i.scdn.co/image/ab67616d0000b2738e4986...
# 3            20/10/2014  https://i.scdn.co/image/ab67616d0000b2731e7c53...
# 4            05/12/1969  https://i.scdn.co/image/ab67616d0000b27373d927...
# ...                 ...                                                ...
# 8616         17/06/2022  https://i.scdn.co/image/ab67616d0000b273e1cafe...
# 8617         24/10/2005  https://i.scdn.co/image/ab67616d0000b273b65ad4...
# 8618         14/08/2000  https://i.scdn.co/image/ab67616d0000b27342781a...
# 8619         06/01/2023  https://i.scdn.co/image/ab67616d0000b273c8fdaf...
# 8620         19/05/2023  https://i.scdn.co/image/ab67616d0000b2730536a8...
#
#       ...   key  loudness  mode  speechiness  acousticness instrumentalness  \
# 0     ...   8.0   -12.305   1.0       0.0480      0.015800         0.112000
# 1     ...   2.0    -5.995   1.0       0.1490      0.014200         0.000021
# 2     ...   7.0    -5.171   1.0       0.0305      0.560000         0.000001
# 3     ...   9.0    -8.920   1.0       0.2590      0.568000         0.000051
# 4     ...   0.0    -9.611   1.0       0.0687      0.675000         0.000073
# ...   ...   ...       ...   ...          ...           ...              ...
# 8616  ...  11.0    -5.570   0.0       0.0562      0.184000         0.000020
# 8617  ...   9.0    -6.373   1.0       0.0340      0.000354         0.011200
# 8618  ...   9.0    -6.802   0.0       0.0389      0.000132         0.088900
# 8619  ...   1.0    -4.923   0.0       0.1830      0.060700         0.000263
# 8620  ...   5.0    -7.930   1.0       0.2460      0.214000         0.001160
#
#      liveness  valence    tempo  time_signature
# 0      0.4080    0.504  111.458             4.0
# 1      0.2370    0.800  127.045             4.0
# 2      0.3380    0.706   74.981             4.0
# 3      0.0384    0.833   75.311             4.0
# 4      0.2890    0.497   85.818             4.0
# ...       ...      ...      ...             ...
# 8616   0.3090    0.400  125.975             4.0
# 8617   0.3380    0.767  130.978             4.0
# 8618   0.3610    0.626  123.037             4.0
# 8619   0.3460    0.420  122.060             4.0
# 8620   0.1030    0.711  128.103             4.0
#
# [8621 rows x 29 columns]

# %%
# Out:
#                     track_id      track_name  \
# 3822  24yDQWnPh85du5UBWTGIKL  Cradle Of Love
# 7173  0CRxGsJrwOMQUuTr4yT5mX             Why
# 8327  1C79CxJdMHjk9RkwX04DRh        Applause
#
#                                   artist_id    artist_names  \
# 3822  spotify:artist:1B8n8vtEeexQ5NKehHTkeo  Johnny Preston
# 7173  spotify:artist:5zNOI87gG4RttFmYAZWaxQ  Frankie Avalon
# 8327  spotify:artist:1HY2Jd0NmPuamShAr6KMms       Lady Gaga
#
#                     album_id        album_name         album_artist_id  \
# 3822  1LOwHourc3GtqJXwRHNlo9  Above The Clouds  1B8n8vtEeexQ5NKehHTkeo
# 7173  1mh6ZNXSK0kCLebYxFXTSO       Beach Party  5zNOI87gG4RttFmYAZWaxQ
# 8327  535qZk6ycJqQaa5qFPmq3k            ARTPOP  1HY2Jd0NmPuamShAr6KMms
#
#      album_artist_names album_release_date  \
# 3822     Johnny Preston         20/06/2013
# 7173     Frankie Avalon         04/12/2013
# 8327          Lady Gaga         01/01/2013
#
#                                         album_image_url  ...  key  loudness  \
# 3822  https://i.scdn.co/image/ab67616d0000b27386577e...  ...  6.0    -6.727
# 7173  https://i.scdn.co/image/ab67616d0000b273e16584...  ...  5.0    -8.677
# 8327  https://i.scdn.co/image/ab67616d0000b273652e65...  ...  7.0    -4.277
#
#       mode  speechiness  acousticness instrumentalness liveness  valence  \
# 3822   0.0       0.0531        0.2860         0.012500   0.0863    0.804
# 7173   1.0       0.0264        0.7620         0.000000   0.1300    0.586
# 8327   0.0       0.0519        0.0228         0.000002   0.1250    0.713
#
#         tempo  time_signature
# 3822   87.703             4.0
# 7173   94.267             4.0
# 8327  139.906             4.0
#
# [3 rows x 29 columns]
